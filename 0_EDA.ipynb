# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('player_dataset.csv')

# %%
df.head()
# Out:
#                 name Team_y Position_y HANDED  GP   G   A   P  P/GP  +/-  ...  \
# 0  Zemgus Girgensons    BUF          C   Left  68  12   7  19  0.28   -1  ...
# 1         Zack Smith    CHI          C   Left  50   4   7  11  0.22    2  ...
# 2       Zack Kassian    EDM          W  Right  59  15  19  34  0.58    0  ...
# 3        Zach Parise    MIN          W   Left  69  25  21  46  0.67  -11  ...
# 4         Zach Hyman    TOR          W  Right  51  21  16  37  0.73   13  ...
#
#        SALARY  CF_perc FF_perc  xGF_perc PIM Giveaways Takeaways Hits  \
# 0  $1,600,000    41.77   41.89     40.84  10        11        13  110
# 1  $3,250,000    42.62   41.46     39.88  29        14        21  112
# 2  $2,000,000    49.10   49.47     47.26  69        45        26  157
# 3  $9,000,000    52.74   52.41     57.12   8        22        21   27
# 4  $2,500,000    50.48   50.23     53.20  23        16        32   52
#
#    Hits Taken blocked_shots
# 0          71            20
# 1          71            18
# 2          54             8
# 3          60            38
# 4         101            23
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['name', 'Team_y', 'Position_y', 'HANDED', 'GP', 'G', 'A', 'P', 'P/GP',
#        '+/-', 'Sh', 'Sh_perc', 'TOI_x', 'TOI_dec', 'CLAUSE', 'EXPIRY',
#        'CAPHIT', 'CAP HIT %', 'cap_hit_perc', 'SALARY', 'CF_perc', 'FF_perc',
#        'xGF_perc', 'PIM', 'Giveaways', 'Takeaways', 'Hits', 'Hits Taken',
#        'blocked_shots'],
#       dtype='object')
